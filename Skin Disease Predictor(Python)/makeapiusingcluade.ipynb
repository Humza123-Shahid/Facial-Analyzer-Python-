# %%
from google.colab import drive
import shutil
shutil.copy("/content/drive/MyDrive/Dataset/skin_disease_resnet50v2.keras", "/content/skin_disease_resnet50v2.keras")
print("Model restored successfully!")
# Out:
# Model restored successfully!

# %%
# !pip install -q fastapi uvicorn python-multipart pyngrok nest-asyncio

# %%
# !pip install opencv-python-headless
# Out:
# Requirement already satisfied: opencv-python-headless in /usr/local/lib/python3.13/dist-packages (5.0.0.93)
# Requirement already satisfied: numpy>=2 in /usr/local/lib/python3.13/dist-packages (from opencv-python-headless) (2.1.3)

# %%
# Cell 1: Remove old cached app module
import sys
if 'app' in sys.modules:
    del sys.modules['app']

import os
if os.path.exists('app.py'):
    os.remove('app.py')
print("Cleared old app.py and module cache")
# Out:
# Cleared old app.py and module cache

# %%
# %%writefile app.py
import io
import math
import base64
import numpy as np
import cv2
from fastapi import FastAPI, UploadFile, File, HTTPException
from fastapi.middleware.cors import CORSMiddleware
from pydantic import BaseModel
from PIL import Image
import tensorflow as tf

app = FastAPI(title="Skin Disease Prediction API")

app.add_middleware(
    CORSMiddleware,
    allow_origins=["*"],
    allow_credentials=True,
    allow_methods=["*"],
    allow_headers=["*"],
)

MODEL_PATH = "skin_disease_resnet50v2.keras"
IMG_SIZE = (260, 260)
TTA_STEPS = 8
CLASS_NAMES = [
    "Acne",
    "Blackheads",
    "Dark-Spots",
    "Dry-Skin",
    "Englarged-Pores",   # ← typo with 'l' — keep as-is to match folder
    "Eyebags",
    "Normal Skin",       # ← SPACE not dash — this was your bug!
    "Not-Skin",
    "Oily-Skin",
    "Skin-Redness",
    "Whiteheads",
    "Wrinkles"
]

class FocalLoss(tf.keras.losses.Loss):
    def __init__(self, gamma=2.0, label_smoothing=0.1, **kwargs):
        super().__init__(**kwargs)
        self.gamma = gamma
        self.label_smoothing = label_smoothing

    def call(self, y_true, y_pred):
        n_cls  = tf.cast(tf.shape(y_true)[-1], tf.float32)
        y_true = y_true * (1.0 - self.label_smoothing) + self.label_smoothing / n_cls
        y_pred = tf.clip_by_value(y_pred, 1e-7, 1.0 - 1e-7)
        ce     = -y_true * tf.math.log(y_pred)
        weight = tf.pow(1.0 - y_pred, self.gamma)
        focal  = weight * ce
        return tf.reduce_mean(tf.reduce_sum(focal, axis=-1))

    def get_config(self):
        cfg = super().get_config()
        cfg.update({"gamma": self.gamma, "label_smoothing": self.label_smoothing})
        return cfg
model = None

@app.on_event("startup")
def load_model():
    global model
    try:
        model = tf.keras.models.load_model(MODEL_PATH, custom_objects={"FocalLoss": FocalLoss})
        print("Successfully loaded Keras model inside Colab.")
    except Exception as e:
        print(f"Error loading model: {e}")

resnet_preprocess = tf.keras.applications.resnet_v2.preprocess_input

def random_rotate_tf(image, max_deg=25.0):
    angle = tf.random.uniform([], -max_deg, max_deg) * (math.pi / 180.0)
    ca, sa = tf.math.cos(angle), tf.math.sin(angle)
    h, w = tf.cast(tf.shape(image)[0], tf.float32), tf.cast(tf.shape(image)[1], tf.float32)
    cx, cy = w / 2.0, h / 2.0
    t = [ca, -sa, cx - cx*ca + cy*sa, sa, ca, cy - cx*sa - cy*ca, 0.0, 0.0]
    t = tf.reshape(tf.stack(t), [1, 8])
    return tf.raw_ops.ImageProjectiveTransformV3(
        images=tf.expand_dims(image, 0), transforms=t,
        output_shape=tf.shape(image)[:2],
        interpolation="BILINEAR", fill_mode="REFLECT", fill_value=0.0)[0]

def random_zoom_tf(image, lo=0.85, hi=1.15):
    factor = tf.random.uniform([], lo, hi)
    h, w = tf.shape(image)[0], tf.shape(image)[1]
    new_h = tf.maximum(tf.cast(tf.cast(h, tf.float32) / factor, tf.int32), 1)
    new_w = tf.maximum(tf.cast(tf.cast(w, tf.float32) / factor, tf.int32), 1)
    image = tf.image.resize_with_crop_or_pad(image, new_h, new_w)
    return tf.image.resize_with_crop_or_pad(image, h, w)

def augment_image(image_tensor):
    image = tf.image.random_flip_left_right(image_tensor)
    image = tf.image.random_flip_up_down(image)
    image = tf.image.random_brightness(image, 0.30)
    image = tf.image.random_contrast(image, 0.70, 1.30)
    image = tf.image.random_saturation(image, 0.60, 1.40)
    image = tf.image.random_hue(image, 0.06)
    image = random_rotate_tf(image, max_deg=25.0)
    image = random_zoom_tf(image, lo=0.85, hi=1.15)
    return tf.clip_by_value(image, 0.0, 255.0)

def has_enough_skin(image_bytes: bytes, min_skin_ratio: float = 0.05) -> bool:
    """Check if image contains enough skin pixels to be a valid skin condition image."""
    # Decode bytes directly instead of reading from file path
    nparr = np.frombuffer(image_bytes, np.uint8)
    img = cv2.imdecode(nparr, cv2.IMREAD_COLOR)

    if img is None:
        return False

    img_ycrcb = cv2.cvtColor(img, cv2.COLOR_BGR2YCrCb)

    lower = np.array([0, 133, 77], dtype=np.uint8)
    upper = np.array([255, 173, 127], dtype=np.uint8)

    skin_mask = cv2.inRange(img_ycrcb, lower, upper)
    skin_ratio = np.sum(skin_mask > 0) / skin_mask.size

    print(f"Skin pixel ratio: {skin_ratio:.2%}")
    return skin_ratio >= min_skin_ratio

def run_prediction(contents: bytes, use_tta: bool):
    if model is None:
        raise HTTPException(status_code=500, detail="Model not loaded on server.")

    if not has_enough_skin(contents):
        return {
        "success": False,
        "detail":"Image does not appear to contain sufficient skin. Please upload a clear photo of the affected skin area."
        }

    img_pil = Image.open(io.BytesIO(contents)).convert("RGB").resize(IMG_SIZE)
    img_f = tf.cast(np.array(img_pil), tf.float32)
    orig = resnet_preprocess(img_f)

    if use_tta:
        batch = [orig] + [resnet_preprocess(augment_image(img_f)) for _ in range(TTA_STEPS - 1)]
        batch = tf.stack(batch)
        aug_probs = model.predict(batch, verbose=0)
    else:
        aug_probs = model.predict(tf.expand_dims(orig, 0), verbose=0)

    final_probs = np.mean(aug_probs, axis=0)
    top5_indices = final_probs.argsort()[-5:][::-1]

    predictions = [
        {"class_name": CLASS_NAMES[idx] if idx < len(CLASS_NAMES) else f"Class {idx}", "confidence": float(final_probs[idx])}
        for idx in top5_indices
    ]

    return {
        "success": True,
        "prediction": predictions[0]["class_name"],
        "confidence": predictions[0]["confidence"],
        "top_5": predictions
    }

# ── Multipart form-data endpoint (used by the HTML/Colab camera frontend) ──
@app.post("/predict")
async def predict(file: UploadFile = File(...), use_tta: bool = True):
    if not file.content_type or not file.content_type.startswith("image/"):
        raise HTTPException(status_code=400, detail="Uploaded file must be an image.")
    try:
        contents = await file.read()
        return run_prediction(contents, use_tta)
    except HTTPException:
        raise
    except Exception as e:
        raise HTTPException(status_code=500, detail=f"Prediction failed: {str(e)}")

# ── JSON + base64 endpoint (used by the React Native app) ──
class ImagePayload(BaseModel):
    file: str
    use_tta: bool = True

@app.post("/predict_base64")
async def predict_base64(payload: ImagePayload):
    try:
        try:
            contents = base64.b64decode(payload.file)
        except Exception:
            raise HTTPException(status_code=400, detail="Invalid base64 image data.")
        return run_prediction(contents, payload.use_tta)
    except HTTPException:
        raise
    except Exception as e:
        raise HTTPException(status_code=500, detail=f"Prediction failed: {str(e)}")

@app.get("/health")
async def health():
    return {"status": "ok", "model_loaded": model is not None}
# Out:
# Writing app.py

# %%
# Cell 2: Verify the file was written correctly
with open('app.py', 'r') as f:
    content = f.read()

# Check CLASS_NAMES is correct
assert '"Normal Skin"' in content, "ERROR: Normal Skin missing!"
assert '"Not-Skin"' in content, "ERROR: Not-Skin missing!"
assert 'return tf.reduce_mean(y_pred)' not in content, "ERROR: broken FocalLoss still there!"
print("✅ app.py looks correct")
# Out:
# ✅ app.py looks correct

# %%
NGROK_AUTH_TOKEN = "3EcbqslQldpKUsNj23I71wn2MXi_6jZSqwXg68NqmtKr25TML"
from pyngrok import ngrok
ngrok.set_auth_token(NGROK_AUTH_TOKEN)

# %%
import nest_asyncio, uvicorn
from pyngrok import ngrok

ngrok.kill()  # close any leftover tunnels from previous runs
nest_asyncio.apply()

from app import app  # imports the FastAPI app defined in app.py

PORT = 8000
public_url = ngrok.connect(PORT).public_url
print(f"Public API URL: {public_url}")
print(f"Predict route : {public_url}/predict?use_tta=false")
print(f"Docs          : {public_url}/docs")

config = uvicorn.Config(app, host="0.0.0.0", port=PORT, loop="asyncio")
server = uvicorn.Server(config)
await server.serve()

#old code now using cloudfare tunnel
# Out:
# [TUNNEL] 2026-09-10T08:14:54Z INF Initiating graceful shutdown due to signal interrupt ...
# [UVICORN] INFO:     Shutting down
# [UVICORN] INFO:     Waiting for application shutdown.
# [UVICORN] INFO:     Application shutdown complete.
# [UVICORN] INFO:     Finished server process [3242]
# [TUNNEL] 2026-09-10T08:14:54Z INF Unregistered tunnel connection connIndex=0 event=0 ip=198.41.192.27
# [TUNNEL] 2026-09-10T08:14:54Z ERR Connection terminated connIndex=0
# [TUNNEL] 2026-09-10T08:14:54Z ERR no more connections active and exiting
# [TUNNEL] 2026-09-10T08:14:54Z INF Tunnel server stopped
# [TUNNEL] 2026-09-10T08:14:54Z INF Metrics server stopped
# WARNING:pyngrok.process.ngrok:t=2026-09-10T08:14:55+0000 lvl=warn msg="failed to start tunnel" pg=/api/tunnels id=fcad2c2f22bd11cc err="failed to start tunnel: The endpoint 'https://greeter-darling-prowess.ngrok-free.dev' is already online. Either\n1. stop your existing endpoint first, or\n2. start both endpoints with `--pooling-enabled` to load balance between them.\r\n\r\nERR_NGROK_334\r\n"
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /usr/local/lib/python3.13/dist-packages/pyngrok/ngrok.py in api_request(url, method, data, params, timeout, auth)
#     631     try:
# --> 632         response = urlopen(request, encoded_data, timeout)
#     633         response_data = response.read().decode("utf-8")
#
# /usr/lib/python3.13/urllib/request.py in urlopen(url, data, timeout, context)
#     188         opener = _opener
# --> 189     return opener.open(url, data, timeout)
#     190
#
# /usr/lib/python3.13/urllib/request.py in open(self, fullurl, data, timeout)
#     494             meth = getattr(processor, meth_name)
# --> 495             response = meth(req, response)
#     496
#
# /usr/lib/python3.13/urllib/request.py in http_response(self, request, response)
#     603         if not (200 <= code < 300):
# --> 604             response = self.parent.error(
#     605                 'http', request, response, code, msg, hdrs)
#
# /usr/lib/python3.13/urllib/request.py in error(self, proto, *args)
#     532             args = (dict, 'default', 'http_error_default') + orig_args
# --> 533             return self._call_chain(*args)
#     534
#
# /usr/lib/python3.13/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     465             func = getattr(handler, meth_name)
# --> 466             result = func(*args)
#     467             if result is not None:
#
# /usr/lib/python3.13/urllib/request.py in http_error_default(self, req, fp, code, msg, hdrs)
#     612     def http_error_default(self, req, fp, code, msg, hdrs):
# --> 613         raise HTTPError(req.full_url, code, msg, hdrs, fp)
#     614
#
# HTTPError: HTTP Error 502: Bad Gateway
#
# During handling of the above exception, another exception occurred:
#
# PyngrokNgrokHTTPError                     Traceback (most recent call last)
# /tmp/ipykernel_2349/1345457895.py in <cell line: 0>()
#       8
#       9 PORT = 8000
# ---> 10 public_url = ngrok.connect(PORT).public_url
#      11 print(f"Public API URL: {public_url}")
#      12 print(f"Predict route : {public_url}/predict?use_tta=false")
#
# /usr/local/lib/python3.13/dist-packages/pyngrok/ngrok.py in connect(addr, proto, name, pyngrok_config, **options)
#     391     logger.debug(f"Creating tunnel with options: {options}")
#     392
# --> 393     tunnel = NgrokTunnel(api_request(f"{api_url}{api_path}", method="POST", data=options,
#     394                                      timeout=pyngrok_config.request_timeout),
#     395                          pyngrok_config, api_url)
#
# /usr/local/lib/python3.13/dist-packages/pyngrok/ngrok.py in api_request(url, method, data, params, timeout, auth)
#     651         logger.debug(f"Response {status_code}: {response_data.strip()}")
#     652
# --> 653         raise PyngrokNgrokHTTPError(f"ngrok client exception, API returned {status_code}: {response_data}",
#     654                                     e.url,
#     655                                     status_code, e.reason, e.headers, response_data)
#
# PyngrokNgrokHTTPError: ngrok client exception, API returned 502: {"error_code":103,"status_code":502,"msg":"failed to start tunnel","details":{"err":"failed to start tunnel: The endpoint 'https://greeter-darling-prowess.ngrok-free.dev' is already online. Either\n1. stop your existing endpoint first, or\n2. start both endpoints with `--pooling-enabled` to load balance between them.\r\n\r\nERR_NGROK_334\r\n"}}

# %%
# !wget -q https://github.com/cloudflare/cloudflared/releases/latest/download/cloudflared-linux-amd64 -O cloudflared
# !chmod +x cloudflared
# !mv cloudflared /usr/local/bin/
# !cloudflared --version  # confirm it installed correctly
# Out:
# cloudflared version 2026.9.0 (built 2026-09-09-16:30 UTC)

# %%
import subprocess
import time
import re
import os
import signal
import threading
import urllib.request

# 1. Clear everything completely
def deep_cleanup():
    try:
        pids = subprocess.check_output(["lsof", "-t", "-i:8000"]).decode().strip().split("\n")
        for pid in pids:
            if pid:
                os.kill(int(pid), signal.SIGKILL)
    except Exception as e:
        print(f"[cleanup] lsof check failed: {e}")

    subprocess.run(["pkill", "-9", "-f", "cloudflared"])
    subprocess.run(["pkill", "-9", "-f", "uvicorn"])

    # actively wait until port 8000 is free instead of a blind sleep
    for _ in range(20):
        try:
            pids = subprocess.check_output(["lsof", "-t", "-i:8000"]).decode().strip()
            if not pids:
                break
        except subprocess.CalledProcessError:
            break  # no process on port = lsof returns nonzero
        time.sleep(0.5)

deep_cleanup()
time.sleep(1)

# 2. Launch Uvicorn
print("Launching Uvicorn...")
uvicorn_process = subprocess.Popen(
    ["uvicorn", "app:app", "--host", "127.0.0.1", "--port", "8000"],
    stdout=subprocess.PIPE,
    stderr=subprocess.STDOUT,
    text=True,
    bufsize=1
)

# A background thread to read and print Uvicorn logs so the stream never blocks
def log_reader(pipe, label):
    for line in iter(pipe.readline, ""):
        print(f"[{label}] {line.strip()}")

uvicorn_thread = threading.Thread(target=log_reader, args=(uvicorn_process.stdout, "UVICORN"), daemon=True)
uvicorn_thread.start()

# Wait to let Uvicorn finish initialization and model loading
print("Waiting 8 seconds for application startup and model loading...")
time.sleep(8)

# Check for instant failure
if uvicorn_process.poll() is not None:
    raise RuntimeError("❌ Uvicorn failed to start. Review the UVICORN logs above.")

# 3. Start Cloudflare Tunnel
print("Launching Cloudflare Tunnel...")
tunnel_process = subprocess.Popen(
    ["cloudflared", "tunnel", "--url", "http://127.0.0.1:8000", "--protocol", "http2"],
    stdout=subprocess.PIPE,
    stderr=subprocess.STDOUT,
    text=True,
    bufsize=1
)

# 4. Catch the URL dynamically
public_url = None
start_time = time.time()
timeout = 30

print("Waiting for Cloudflare public URL...")
public_url = None
registered_connections = 0
start_time = time.time()
timeout = 40

while time.time() - start_time < timeout:
    line = tunnel_process.stdout.readline()
    if not line:
        break
    log = line.strip()
    if log:
        print(f"[TUNNEL] {log}", flush=True)

    if "trycloudflare.com" in log and not public_url:
        match = re.search(r'https://[a-z0-9\-]+\.trycloudflare\.com', log)
        if match:
            public_url = match.group(0)

    if "Registered tunnel connection" in log:
        registered_connections += 1
        if registered_connections >= 1 and public_url:
            print(f"✅ Tunnel connection registered: {public_url}", flush=True)
            break
# while time.time() - start_time < timeout:
#     line = tunnel_process.stdout.readline()
#     if not line:
#         break

#     log = line.strip()
#     if log:
#         print(f"[TUNNEL] {log}") # Show what cloudflared is doing

#     if "trycloudflare.com" in log:
#         match = re.search(r'https://[a-z0-9\-]+\.trycloudflare\.com', log)
#         if match:
#             public_url = match.group(0)
#             print("\n" + "🎉 " * 10)
#             print(f"Public API URL : {public_url}")
#             print(f"Predict route  : {public_url}/predict?use_tta=false")
#             print(f"Docs UI URL    : {public_url}/docs")
#             print("🎉 " * 10 + "\n")
#             break

def wait_until_live(url, timeout=40):
    start = time.time()
    last_err = None
    req_url = url + "/docs"
    while time.time() - start < timeout:
        try:
            req = urllib.request.Request(req_url, headers={"User-Agent": "Mozilla/5.0"})
            resp = urllib.request.urlopen(req, timeout=5)
            if resp.status == 200:
                return True
        except Exception as e:
            last_err = e
        time.sleep(2)
    print(f"[DEBUG] Last error while checking {req_url}: {last_err}")
    return False

if public_url and wait_until_live(public_url):
    print(f"✅ Live: {public_url}")
else:
    print("❌ Tunnel came up but backend isn't reachable yet — check UVICORN/TUNNEL logs above.")
# if not public_url:
#     print("❌ Could not obtain public URL within timeout limit.")

# 5. Keep tunnel stream alive in background so it doesn't choke either
tunnel_thread = threading.Thread(target=log_reader, args=(tunnel_process.stdout, "TUNNEL"), daemon=True)
tunnel_thread.start()
# Out:
# [cleanup] lsof check failed: Command '['lsof', '-t', '-i:8000']' returned non-zero exit status 1.
# Launching Uvicorn...
# Waiting 8 seconds for application startup and model loading...
# [UVICORN] INFO:     Started server process [9194]
# [UVICORN] INFO:     Waiting for application startup.
# [UVICORN] 2026-09-10 08:15:26.210320: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# Launching Cloudflare Tunnel...
# Waiting for Cloudflare public URL...
# [TUNNEL] 2026-09-10T08:15:27Z INF Thank you for trying Cloudflare Tunnel. Doing so, without a Cloudflare account, is a quick way to experiment and try it out. However, be aware that these account-less Tunnels have no uptime guarantee, are subject to the Cloudflare Online Services Terms of Use (https://www.cloudflare.com/website-terms/), and Cloudflare reserves the right to investigate your use of Tunnels for violations of such terms. If you intend to use Tunnels in production you should use a pre-created named tunnel by following: https://developers.cloudflare.com/cloudflare-one/connections/connect-apps
# [TUNNEL] 2026-09-10T08:15:27Z INF Requesting new quick Tunnel on trycloudflare.com...
# [UVICORN] /usr/local/lib/python3.13/dist-packages/keras/src/saving/saving_lib.py:797: UserWarning: Skipping variable loading for optimizer 'adam', because it has 169 variables whereas the saved optimizer has 173 variables.
# [UVICORN] saveable.load_own_variables(weights_store.get(inner_path))
# [UVICORN] INFO:     Application startup complete.
# [UVICORN] INFO:     Uvicorn running on http://127.0.0.1:8000 (Press CTRL+C to quit)
# [TUNNEL] 2026-09-10T08:15:31Z INF +--------------------------------------------------------------------------------------------+
# [TUNNEL] 2026-09-10T08:15:31Z INF |  Your quick Tunnel has been created! Visit it at (it may take some time to be reachable):  |
# [TUNNEL] 2026-09-10T08:15:31Z INF |  https://isa-accounting-ticket-coordinator.trycloudflare.com                               |
# [TUNNEL] 2026-09-10T08:15:31Z INF +--------------------------------------------------------------------------------------------+
# [TUNNEL] 2026-09-10T08:15:31Z INF Cannot determine default configuration path. No file [config.yml config.yaml] in [~/.cloudflared ~/.cloudflare-warp ~/cloudflare-warp /etc/cloudflared /usr/local/etc/cloudflared]
# [TUNNEL] 2026-09-10T08:15:31Z INF Version 2026.9.0 (Checksum 53b7a7a5420d188758d24341294acb0d1bca54296548ac05e38811a694ac6134)
# [TUNNEL] 2026-09-10T08:15:31Z INF GOOS: linux, GOVersion: go1.26.8, GoArch: amd64
# [TUNNEL] 2026-09-10T08:15:31Z INF Settings: map[ha-connections:1 p:http2 protocol:http2 url:http://127.0.0.1:8000]
# [TUNNEL] 2026-09-10T08:15:31Z INF Autoupdate frequency is set autoupdateFreq=86400000
# [TUNNEL] 2026-09-10T08:15:31Z INF Generated Connector ID: a958ec29-332e-469b-ad20-84334ad440ea
# [TUNNEL] 2026-09-10T08:15:31Z INF Initial protocol http2
# [TUNNEL] 2026-09-10T08:15:31Z INF ICMP proxy will use 172.28.0.12 as source for IPv4
# [TUNNEL] 2026-09-10T08:15:31Z INF ICMP proxy will use ::1 in zone lo as source for IPv6
# [TUNNEL] 2026/09/10 08:15:31 failed to sufficiently increase receive buffer size (was: 208 kiB, wanted: 7168 kiB, got: 416 kiB). See https://github.com/quic-go/quic-go/wiki/UDP-Buffer-Sizes for details.
# [TUNNEL] 2026-09-10T08:15:31Z INF ICMP proxy will use 172.28.0.12 as source for IPv4
# [TUNNEL] 2026-09-10T08:15:31Z INF ICMP proxy will use ::1 in zone lo as source for IPv6
# [TUNNEL] 2026-09-10T08:15:31Z INF Starting metrics server on 127.0.0.1:20241/metrics
# [TUNNEL] 2026-09-10T08:15:31Z INF Tunnel connection curve preferences: [X25519MLKEM768 CurveID(65074) CurveP256] connIndex=0 event=0 ip=198.41.192.167
# [TUNNEL] 2026-09-10T08:15:31Z INF Registered tunnel connection connIndex=0 connection=cad7b231-42e7-4021-affa-c17e81aba229 event=0 ip=198.41.192.167 location=lax09 protocol=http2
# ✅ Tunnel connection registered: https://isa-accounting-ticket-coordinator.trycloudflare.com
# [UVICORN] Successfully loaded Keras model inside Colab.
# [UVICORN] INFO:     34.16.249.250:0 - "GET /docs HTTP/1.1" 200 OK
# ✅ Live: https://isa-accounting-ticket-coordinator.trycloudflare.com
# [TUNNEL] 2026-09-10T08:15:37Z INF +--------------------------------------------------------------------------------------+
# [TUNNEL] 2026-09-10T08:15:37Z INF |                               CONNECTIVITY PRE-CHECKS                                |
# [TUNNEL] 2026-09-10T08:15:37Z INF +--------------------------------------------------------------------------------------+
# [TUNNEL] 2026-09-10T08:15:37Z INF |  COMPONENT         TARGET                     STATUS  DETAILS                        |
# [TUNNEL] 2026-09-10T08:15:37Z INF |  DNS Resolution    region1.v2.argotunnel.com  PASS    DNS Resolved successfully      |
# [TUNNEL] 2026-09-10T08:15:37Z INF |  DNS Resolution    region2.v2.argotunnel.com  PASS    DNS Resolved successfully      |
# [TUNNEL] 2026-09-10T08:15:37Z INF |  UDP Connectivity  region1.v2.argotunnel.com  PASS    QUIC connection successful     |
# [TUNNEL] 2026-09-10T08:15:37Z INF |  UDP Connectivity  region2.v2.argotunnel.com  PASS    QUIC connection successful     |
# [TUNNEL] 2026-09-10T08:15:37Z INF |  TCP Connectivity  region1.v2.argotunnel.com  PASS    HTTP/2 connection successful   |
# [TUNNEL] 2026-09-10T08:15:37Z INF |  TCP Connectivity  region2.v2.argotunnel.com  PASS    HTTP/2 connection successful   |
# [TUNNEL] 2026-09-10T08:15:37Z INF |  Cloudflare API    api.cloudflare.com:443     PASS    API is reachable               |
# [TUNNEL] 2026-09-10T08:15:37Z INF |                                                                                      |
# [TUNNEL] 2026-09-10T08:15:37Z INF |  SUMMARY: Environment is healthy. cloudflared will use 'http2' as primary protocol.  |
# [TUNNEL] 2026-09-10T08:15:37Z INF +--------------------------------------------------------------------------------------+
# [TUNNEL] 2026-09-10T08:15:37Z INF precheck component="DNS Resolution" details="DNS Resolved successfully" run_id=9b6b293f-ab05-4bcd-91c3-b31072145217 status=pass target=region1.v2.argotunnel.com
# [TUNNEL] 2026-09-10T08:15:37Z INF precheck component="DNS Resolution" details="DNS Resolved successfully" run_id=9b6b293f-ab05-4bcd-91c3-b31072145217 status=pass target=region2.v2.argotunnel.com
# [TUNNEL] 2026-09-10T08:15:37Z INF precheck component="UDP Connectivity" details="QUIC connection successful" run_id=9b6b293f-ab05-4bcd-91c3-b31072145217 status=pass target=region1.v2.argotunnel.com
# [TUNNEL] 2026-09-10T08:15:37Z INF precheck component="UDP Connectivity" details="QUIC connection successful" run_id=9b6b293f-ab05-4bcd-91c3-b31072145217 status=pass target=region2.v2.argotunnel.com
# [TUNNEL] 2026-09-10T08:15:37Z INF precheck component="TCP Connectivity" details="HTTP/2 connection successful" run_id=9b6b293f-ab05-4bcd-91c3-b31072145217 status=pass target=region1.v2.argotunnel.com
# [TUNNEL] 2026-09-10T08:15:37Z INF precheck component="TCP Connectivity" details="HTTP/2 connection successful" run_id=9b6b293f-ab05-4bcd-91c3-b31072145217 status=pass target=region2.v2.argotunnel.com
# [TUNNEL] 2026-09-10T08:15:37Z INF precheck component="Cloudflare API" details="API is reachable" run_id=9b6b293f-ab05-4bcd-91c3-b31072145217 status=pass target=api.cloudflare.com:443
# [TUNNEL] 2026-09-10T08:15:37Z INF precheck complete hard_fail=false run_id=9b6b293f-ab05-4bcd-91c3-b31072145217 suggested_protocol=http2
