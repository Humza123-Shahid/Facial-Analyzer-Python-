# %%
from IPython.display import HTML, display

html_code = """
<!DOCTYPE html>
<html>
<head>
    <style>

        body { font-family: Arial, sans-serif; padding: 15px; background-color: #f4f4f9;}
        .box { background: white; padding: 25px; border-radius: 10px; box-shadow: 0 4px 6px rgba(0,0,0,0.1); max-width: 450px; }
        input[type="file"] { margin: 15px 0; display: block; }
        button { background-color: #28a745; color: white; border: none; padding: 10px 20px; border-radius: 5px; cursor: pointer; font-size: 14px; }
        button:hover { background-color: #218838; }
        pre { background: #272822; color: #f8f8f2; padding: 15px; border-radius: 5px; max-height: 250px; overflow-y: auto; font-size: 13px; }
        #imgPreview { max-width: 100%; max-height: 200px; margin-top: 10px; display: none; border-radius: 5px; }
        #jsonResult {
            margin-top: 15px;
            font-size: 14px;
            color: #4a5568;
        }
        /* --- Card Specific Layouts --- */
        .analysis-card {
            background: #ffffff;
            padding: 14px;
            border-radius: 12px;
            border: 1px solid #edf2f7;
            width: 100%;
            box-sizing: border-box;
            margin-top: 10px;
        }

        .card-header {
            margin-bottom: 12px;
            border-bottom: 1px solid #edf2f7;
            padding-bottom: 8px;
            overflow: hidden;
        }

        .card-header h2 {
            margin: 0;
            font-size: 1.1rem;
            font-weight: 700;
            float: left;
            color: #1a202c;
        }

        .status-badge {
            background-color: #def7ec;
            color: #03543f;
            padding: 2px 8px;
            border-radius: 10px;
            font-size: 0.75rem;
            font-weight: 600;
            float: right;
        }

        .main-prediction {
            background: linear-gradient(135deg, #e0e7ff, #f0f2ff) !important;
            padding: 12px;
            border-radius: 8px;
            text-align: center;
            margin-bottom: 14px;
            clear: both;
        }

        .main-prediction .label {
            font-size: 0.75rem;
            text-transform: uppercase;
            letter-spacing: 0.5px;
            color: #4f46e5;
            font-weight: 700;
        }

        .main-prediction .value {
            font-size: 1.5rem;
            font-weight: 800;
            margin: 4px 0;
            color: #1a202c;
        }

        .main-prediction .confidence {
            font-size: 0.8rem;
            color: #4a5568;
        }

        .breakdown-title {
            font-size: 0.85rem;
            font-weight: 700;
            text-transform: uppercase;
            letter-spacing: 0.5px;
            margin-top: 15px;
            margin-bottom: 10px;
            color: #4a5568;
        }

        .prediction-item {
            margin-bottom: 12px;
            display: block;
        }

        .item-info {
            overflow: hidden;
            margin-bottom: 4px;
            font-size: 0.85rem;
        }

        .item-name {
            font-weight: 600;
            float: left;
            color: #1a202c;
        }

        .item-percentage {
            color: #4a5568;
            font-weight: 700;
            float: right;
        }

        .progress-bar-container {
            background-color: #edf2f7 !important;
            border-radius: 4px;
            height: 8px;
            width: 100%;
            overflow: hidden;
            display: block;
            clear: both;
        }

        .progress-bar {
            background-color: #4f46e5 !important;
            display: block !important;
            height: 8px !important;
            border-radius: 4px;
        }
    </style>
</head>
<body>

<div class="box">
    <h2>Skin Disease Predictor</h2>

    <input type="file" id="skinImage" accept="image/*" onchange="showPreview(event)">
    <img id="imgPreview" />

    <br>
    <button onclick="sendToApi()">Analyze Image</button>

    <h3>Result Summary:</h3>
    <div id="jsonResult">Select an image and click Analyze...</div>
</div>

<script>
function showPreview(event) {
    const reader = new FileReader();
    reader.onload = function() {
        const imgPreview = document.getElementById('imgPreview');
        imgPreview.src = reader.result;
        imgPreview.style.display = 'block';
    }
    reader.readAsDataURL(event.target.files[0]);
}

async function sendToApi() {
    const fileSelector = document.getElementById('skinImage');
    const resultBox = document.getElementById('jsonResult');

    if (fileSelector.files.length === 0) {
        alert("Please upload a medical image first!");
        return;
    }

    resultBox.innerText = "Running Test-Time Augmentation (TTA) batches...";

    const imageFileElement = fileSelector.files[0];
    const formData = new FormData();
    formData.append("file", imageFileElement);

    try {
        // 🔥 CHANGED: Pointing directly to your active secure Localtunnel URL
        const response = await fetch("https://greeter-darling-prowess.ngrok-free.dev/predict?use_tta=false", {
            method: "POST",
            body: formData
        });

        if (!response.ok) throw new Error(`Status: ${response.statusText}`);

        const data = await response.json();

        resultBox.innerText = "";
        resultBox.innerText = JSON.stringify(data, null, 2)

        // Injecting the clean HTML card into our <div> container


    } catch (err) {
        resultBox.innerText = "Error linking to backend: " + err.message;
        console.error(err);
    }
}
</script>

</body>
</html>
"""
#resultBox.innerText = JSON.stringify(data, null, 2);
#<pre id="jsonResult">Select an image and click Analyze...</pre>
# resultBox.innerHTML = `
#         <div class="analysis-card">
#             <div class="card-header">
#                 <h2>Analysis Results</h2>
#                 <span class="status-badge">Success</span>
#             </div>

#             <div class="main-prediction">
#                 <div class="label">Top Prediction</div>
#                 <div class="value">Eyebags</div>
#                 <div class="confidence">Confidence: <strong>41.2%</strong></div>
#             </div>

#             <div class="breakdown-title">All Matches</div>

#             <div class="prediction-list">
#                 <div class="prediction-item">
#                     <div class="item-info">
#                         <span class="item-name">Eyebags</span>
#                         <span class="item-percentage">41.2%</span>
#                     </div>
#                     <div class="progress-bar-container">
#                         <div class="progress-bar" style="width: 41.2%;"></div>
#                     </div>
#                 </div>

#                 <div class="prediction-item">
#                     <div class="item-info">
#                         <span class="item-name">Dry Skin</span>
#                         <span class="item-percentage">17.8%</span>
#                     </div>
#                     <div class="progress-bar-container">
#                         <div class="progress-bar" style="width: 17.8%;"></div>
#                     </div>
#                 </div>

#                 <div class="prediction-item">
#                     <div class="item-info">
#                         <span class="item-name">Skin Redness</span>
#                         <span class="item-percentage">8.8%</span>
#                     </div>
#                     <div class="progress-bar-container">
#                         <div class="progress-bar" style="width: 8.8%;"></div>
#                     </div>
#                 </div>

#                 <div class="prediction-item">
#                     <div class="item-info">
#                         <span class="item-name">Acne</span>
#                         <span class="item-percentage">8.0%</span>
#                     </div>
#                     <div class="progress-bar-container">
#                         <div class="progress-bar" style="width: 8.0%;"></div>
#                     </div>
#                 </div>

#                 <div class="prediction-item">
#                     <div class="item-info">
#                         <span class="item-name">Wrinkles</span>
#                         <span class="item-percentage">8.0%</span>
#                     </div>
#                     <div class="progress-bar-container">
#                         <div class="progress-bar" style="width: 8.0%;"></div>
#                     </div>
#                 </div>
#             </div>
#         </div>`
display(HTML(html_code))
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <style>
#
#         body { font-family: Arial, sans-serif; padding: 15px; background-color: #f4f4f9;}
#         .box { background: white; padding: 25px; border-radius: 10px; box-shadow: 0 4px 6px rgba(0,0,0,0.1); max-width: 450px; }
#         input[type="file"] { margin: 15px 0; display: block; }
#         button { background-color: #28a745; color: white; border: none; padding: 10px 20px; border-radius: 5px; cursor: pointer; font-size: 14px; }
#         button:hover { background-color: #218838; }
#         pre { background: #272822; color: #f8f8f2; padding: 15px; border-radius: 5px; max-height: 250px; overflow-y: auto; font-size: 13px; }
#         #imgPreview { max-width: 100%; max-height: 200px; margin-top: 10px; display: none; border-radius: 5px; }
#         #jsonResult {
#             margin-top: 15px;
#             font-size: 14px;
#             color: #4a5568;
#         }
#         /* --- Card Specific Layouts --- */
# ...
